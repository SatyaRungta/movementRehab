# %% [markdown]
# # Setup Environments

# %% [markdown]
# ### For exporting packages in environment
#
# #conda env export > environment.yml

# %% [markdown]
# ### Useful packages
#
# !pip install h5py mat4py scipy tables # For opening *.mat files \n
# !pip install numpy pandas statsmodels # For data cleaning and exploration \n
# !pip install matplotlib plotly seaborn # For data visualisation \n

# %%
# !jupyter --paths

# %%
import os
import sys
sys.executable

# %%
pwd

# %%
import sys
import os
from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib.image as mImg

ROOT_PATH = "E:/ADS/python/ams/isaccade"
os.chdir(ROOT_PATH)

# %% [markdown]
# # Task design

# %% [markdown]
# ![Fig1.jpg](attachment:Fig1.jpg)

# %% [markdown]
# # Experimental setup

# %%
file1 = "/docs/source/images/monkey_head_restraint.jpg"
file2 = "/docs/source/images/monkey_chair.jpg"
file3 = "/docs/source/images/Fig1.jpg"

fpath1 = ROOT_PATH + file1
fpath2 = ROOT_PATH + file2

# %%
img1 = mImg.imread(fpath1)
img2 = mImg.imread(fpath2)

plt.figure(figsize=(10,5))

plt.subplot(121)
plt.imshow(img1)
plt.axis('off')

plt.subplot(122)
plt.imshow(img2)
plt.axis('off')
